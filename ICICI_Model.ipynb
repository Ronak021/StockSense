# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import StandardScaler
from datetime import datetime, timedelta
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# # 1. Data Collection

# %%
def display_tickers(tickers):
    print("\nNifty 50 Company Ticker Symbols (Yahoo Finance Format):")
    print(*tickers, sep=", ")

# %%
tickers_df = pd.read_csv("nifty50_tickers.csv")
tickers = tickers_df['Ticker'].tolist()
display_tickers(tickers)
# Out:
# Nifty 50 Company Ticker Symbols (Yahoo Finance Format):
# ADANIENT.NS, ADANIPORTS.NS, APOLLOHOSP.NS, ASIANPAINT.NS, AXISBANK.NS, BAJAJ-AUTO.NS, BAJFINANCE.NS, BAJAJFINSV.NS, BEL.NS, BPCL.NS, BHARTIARTL.NS, BRITANNIA.NS, CIPLA.NS, COALINDIA.NS, DRREDDY.NS, EICHERMOT.NS, GRASIM.NS, HCLTECH.NS, HDFCBANK.NS, HDFCLIFE.NS, HEROMOTOCO.NS, HINDALCO.NS, HINDUNILVR.NS, ICICIBANK.NS, INDUSINDBK.NS, INFY.NS, ITC.NS, JSWSTEEL.NS, KOTAKBANK.NS, LT.NS, M&M.NS, MARUTI.NS, NESTLEIND.NS, NTPC.NS, ONGC.NS, POWERGRID.NS, RELIANCE.NS, SBILIFE.NS, SHRIRAMFIN.NS, SBIN.NS, SUNPHARMA.NS, TCS.NS, TATACONSUM.NS, TATAMOTORS.NS, TATASTEEL.NS, TECHM.NS, TITAN.NS, TRENT.NS, ULTRACEMCO.NS, WIPRO.NS

# %%
# Ask user for a company
user_input = input("\nPlease enter the name of the company you want to download data for: ").strip()

# Find the corresponding ticker (assumed tickers_df is already defined)
matched_ticker = None
for ticker in tickers_df['Ticker']:
    if ticker.split('.')[0].lower() == user_input.lower():
        matched_ticker = ticker
        break

# Download the data if ticker is found
if matched_ticker:
    folder = 'CSVfiles'  # Ensure the folder name is defined
    try:
        if not os.path.exists(folder):
            os.makedirs(folder)
        
        # Get yesterday's date
        yesterday = (datetime.now() - timedelta(1)).strftime('%Y-%m-%d')
        
        # Download the stock data from 2017 to yesterday's date
        data = yf.download(matched_ticker, start='2017-01-01', end=yesterday)
        data.fillna(0, inplace=True)
        data
        
        # Save to CSV
        filename = os.path.join(folder, f"{matched_ticker}.csv")
        data.to_csv(filename)
        print(f"\nData for {matched_ticker} saved to {filename}")

    except Exception as e:
        print(f"An error occurred while downloading data for {matched_ticker}: {e}")

else:
    print("Company not found in Nifty 50 list.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data for ICICIBANK.NS saved to CSVfiles\ICICIBANK.NS.csv

# %%
yesterday = (datetime.now() - timedelta(1)).strftime('%Y-%m-%d')

stock_data = yf.download(f'{user_input}.NS', start='2017-01-01', end=yesterday)
stock_data.fillna(0, inplace=True)
df = pd.DataFrame(stock_data)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-01-02   233.000000   233.000000   225.545456   229.045456   216.413559
# 2017-01-03   229.181824   232.181824   226.636368   231.272720   218.517990
# 2017-01-04   231.136368   232.500000   227.636368   228.272720   215.683426
# 2017-01-05   230.181824   235.000000   229.272720   233.863632   220.966003
# 2017-01-06   234.772720   237.636368   233.818176   234.681824   221.739059
# ...                 ...          ...          ...          ...          ...
# 2024-11-04  1290.099976  1291.800049  1270.050049  1277.199951  1277.199951
# 2024-11-05  1273.000000  1301.300049  1263.099976  1296.699951  1296.699951
# 2024-11-06  1300.250000  1315.000000  1292.699951  1302.349976  1302.349976
# 2024-11-07  1297.150024  1302.800049  1275.250000  1278.699951  1278.699951
# 2024-11-08  1270.000000  1275.000000  1252.699951  1258.849976  1258.849976
#
#               Volume
# Date
# 2017-01-02  10404350
# 2017-01-03  10236706
# 2017-01-04   6901181
# 2017-01-05  13830668
# 2017-01-06   9055143
# ...              ...
# 2024-11-04  14309121
# 2024-11-05  16431920
# 2024-11-06  12037405
# 2024-11-07   9909035
# 2024-11-08  11195808
#
# [1941 rows x 6 columns]

# %% [markdown]
# # 2. Data Preprocessing

# %%
# This applies the natural logarithm (logarithm with base e) to the Close column of the DataFrame df.
# The reason for taking the logarithm of the closing prices is to stabilize the variance,
#  which can help in time series modeling (especially when working with non-stationary data). 
# Log transformations can reduce the effect of large fluctuations and make the data more stationary.


y = np.log(df["Close"])
y.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
y.asfreq("D")[:15]
# Out:
# Date
# 2017-01-02    5.433920
# 2017-01-03    5.443598
# 2017-01-04    5.430541
# 2017-01-05    5.454738
# 2017-01-06    5.458231
# 2017-01-07         NaN
# 2017-01-08         NaN
# 2017-01-09    5.460359
# 2017-01-10    5.466140
# 2017-01-11    5.483287
# 2017-01-12    5.496982
# 2017-01-13    5.495863
# 2017-01-14         NaN
# 2017-01-15         NaN
# 2017-01-16    5.500516
# Freq: D, Name: Close, dtype: float64

# %% [markdown]
# Let's impute the missing data by forward fill using asfreq method.

# %%
y.asfreq("D", method="ffill")[:15]   # used to forward fill missing values.
# Out:
# Date
# 2017-01-02    5.433920
# 2017-01-03    5.443598
# 2017-01-04    5.430541
# 2017-01-05    5.454738
# 2017-01-06    5.458231
# 2017-01-07    5.458231
# 2017-01-08    5.458231
# 2017-01-09    5.460359
# 2017-01-10    5.466140
# 2017-01-11    5.483287
# 2017-01-12    5.496982
# 2017-01-13    5.495863
# 2017-01-14    5.495863
# 2017-01-15    5.495863
# 2017-01-16    5.500516
# Freq: D, Name: Close, dtype: float64

# %% [markdown]
# Formal of way of test for stationarity. Since the p-value of Augmented Dickey Fullter test is > 0.05,
# we can say that there is not sufficient proof that the time series is stationary.
# Loosely speaking, it is non-stationary. We need further transformation to make data stationary.
# Populary method for making data stationary will be to take "difference".
# Taking difference by lag one, we see the p-val for Dickey Fuller test is < 0.05.
# So we conclude, diff 1 will made the data stationary.

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(prices):
    result=adfuller(prices)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

        
adfuller_test(df['Close'])
# Out:
# ADF Test Statistic : 0.25177330303902035
# p-value : 0.9750204060087524
# #Lags Used : 5
# Number of Observations Used : 1935
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
result = adfuller(y.diff(periods=1).dropna())

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -17.985891
# p-value: 0.000000

# %%
y.diff(periods=1).plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
y
# Out:
# Date
# 2017-01-02    5.433920
# 2017-01-03    5.443598
# 2017-01-04    5.430541
# 2017-01-05    5.454738
# 2017-01-06    5.458231
#                 ...
# 2024-11-04    7.152425
# 2024-11-05    7.167578
# 2024-11-06    7.171926
# 2024-11-07    7.153599
# 2024-11-08    7.137954
# Name: Close, Length: 1941, dtype: float64

# %%
y = y.dropna()

# %% [markdown]
# # 3. Finding the p,d,q

# %% [markdown]
# Identification of an AR model is often best done with the PACF.
#
# For an AR model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model. By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
# Identification of an MA model is often best done with the ACF rather than the PACF. p,d,q
#
# For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner. A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
# p AR model lags d differencing q MA lags

# %%
# Plot ACF and PACF for differenced data

plt.figure(figsize=(12, 8))

# ACF plot
plt.subplot(211)
plot_acf(y.diff(periods=1).dropna(), ax=plt.gca(), lags=50)
plt.title('ACF Plot')


# PACF plot
plt.subplot(212)
plot_pacf(y.diff(periods=1).dropna(), ax=plt.gca(), lags=50)
plt.title('PACF Plot')
plt.show()
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima.model import ARIMA


# fit model
# model = ARIMA(y, order=(5, 1, 0))  # p, d, q
model = ARIMA(y, order=(5, 1, 0))
model_fit = model.fit()

#print(model_fit.summary())

import pandas as pd
import matplotlib.pyplot as plt

# Residual density refers to the distribution of residuals from a statistical model. 
# Residuals are the differences between the observed values and the values predicted by the model.

# Purpose: By examining the residual density, you can assess whether residuals are normally distributed 
# and identify any patterns or anomalies that suggest problems with the model.

# plot residual erros
residuals = pd.DataFrame(model_fit.resid)
# residuals.plot()
# residuals.plot(kind='kde')
# print(residuals.describe())

# Plot residuals density
residuals.plot(kind='kde')
plt.title('Residuals Density')
plt.show()

# Print residuals description
print(residuals.describe())
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                  0
# count  1941.000000
# mean      0.003657
# std       0.124842
# min      -0.185844
# 25%      -0.008641
# 50%       0.000425
# 75%       0.010087
# max       5.433920

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(y, order=(1, 1, 1))
model_fit = model.fit()

#print(model_fit.summary())

import pandas as pd
import matplotlib.pyplot as plt

# Plot residuals density
residuals.plot(kind='kde')
plt.title('Residuals Density')
plt.show()

# Print residuals description
print(residuals.describe())
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                  0
# count  1941.000000
# mean      0.003657
# std       0.124842
# min      -0.185844
# 25%      -0.008641
# 50%       0.000425
# 75%       0.010087
# max       5.433920

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1941
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                4879.099
# Date:                Tue, 12 Nov 2024   AIC                          -9752.198
# Time:                        23:19:48   BIC                          -9735.487
# Sample:                             0   HQIC                         -9746.052
#                                - 1941
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7126      0.207      3.444      0.001       0.307       1.118
# ma.L1         -0.7349      0.196     -3.743      0.000      -1.120      -0.350
# sigma2         0.0004    5.3e-06     72.148      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.85   Jarque-Bera (JB):             11100.43
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.46   Skew:                            -0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.endog
# Out:
# array([[5.43392048],
#        [5.44359762],
#        [5.43054106],
#        ...,
#        [7.17192559],
#        [7.15359918],
#        [7.13795387]])

# %% [markdown]
# # 4 . Data Splitting and Model Fitting

# %% [markdown]
# Spliting the data
# we split the normalized data into training and testing sets :
#
# 70% for training,
# 30% for testing.

# %%
import warnings
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Ignore specific warnings
warnings.filterwarnings("ignore", message="Maximum Likelihood optimization failed to converge")

# Example data setup (ensure y is defined and contains your data)
x = y.values
train_size = int(len(x) * 0.7)
train, test = x[0:train_size], x[train_size:]

history = list(train)  # Use list() to ensure history is a list
predictions = []

# # Use test samples
num_predictions = len(test)
cnt = 0

for t in range(len(test)):
    if cnt == num_predictions:
        break
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()  # No disp argument
    output = model_fit.forecast(steps=1)
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'predicted={yhat:.6f}, actual={obs:.6f}')
    cnt += 1

# Ensure predictions and test have the same length
if len(predictions) != num_predictions:
    raise ValueError(f"Predictions length ({len(predictions)}) does not match expected number ({num_predictions})")

# Slice the test set to match the length of predictions
test_slice = test[:num_predictions]

# Calculate error
error = mean_squared_error(test_slice, predictions)
print(f'Test RMSE: {np.sqrt(error):.3f}')

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(test_slice, label='Actual', color='blue')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Actual vs Predicted Stock Prices')
plt.legend()
plt.show()
# Out:
# predicted=6.557871, actual=6.561314
# predicted=6.563718, actual=6.556636
# predicted=6.557335, actual=6.579390
# predicted=6.577025, actual=6.578487
# predicted=6.577211, actual=6.587481
# predicted=6.587031, actual=6.609349
# predicted=6.608205, actual=6.627644
# predicted=6.628466, actual=6.645741
# predicted=6.644131, actual=6.633187
# predicted=6.634335, actual=6.624331
# predicted=6.627174, actual=6.623268
# predicted=6.626109, actual=6.621672
# predicted=6.623586, actual=6.648985
# predicted=6.646335, actual=6.660127
# predicted=6.658184, actual=6.663260
# predicted=6.662032, actual=6.666957
# predicted=6.666853, actual=6.684674
# predicted=6.686811, actual=6.685736
# predicted=6.686460, actual=6.679976
# predicted=6.680152, actual=6.685237
# predicted=6.685864, actual=6.702697
# predicted=6.703830, actual=6.707596
# predicted=6.706874, actual=6.713442
# predicted=6.712161, actual=6.706557
# predicted=6.707547, actual=6.715141
# predicted=6.716671, actual=6.709609
# predicted=6.710496, actual=6.731257
# predicted=6.730639, actual=6.729764
# predicted=6.729030, actual=6.743765
# predicted=6.743372, actual=6.756584
# predicted=6.755712, actual=6.773538
# predicted=6.774406, actual=6.779069
# predicted=6.778356, actual=6.783608
# predicted=6.784628, actual=6.785701
# predicted=6.787111, actual=6.768953
# predicted=6.771399, actual=6.747880
# predicted=6.749710, actual=6.761457
# predicted=6.762221, actual=6.772279
# predicted=6.771934, actual=6.771191
# predicted=6.768470, actual=6.769470
# predicted=6.767428, actual=6.752095
# predicted=6.754547, actual=6.788183
# predicted=6.788088, actual=6.773481
# predicted=6.773749, actual=6.771248
# predicted=6.770103, actual=6.782702
# predicted=6.781633, actual=6.784061
# predicted=6.787237, actual=6.775594
# predicted=6.774084, actual=6.801061
# predicted=6.800088, actual=6.803783
# predicted=6.804576, actual=6.810363
# predicted=6.809318, actual=6.813445
# predicted=6.812831, actual=6.822306
# predicted=6.824360, actual=6.821762
# predicted=6.821969, actual=6.812455
# predicted=6.813403, actual=6.801505
# predicted=6.802708, actual=6.820835
# predicted=6.821316, actual=6.819197
# predicted=6.818891, actual=6.806165
# predicted=6.805086, actual=6.782475
# predicted=6.783169, actual=6.758153
# predicted=6.761955, actual=6.748232
# predicted=6.749245, actual=6.744648
# predicted=6.743705, actual=6.738034
# predicted=6.735621, actual=6.759255
# predicted=6.755856, actual=6.743293
# predicted=6.742657, actual=6.765788
# predicted=6.764033, actual=6.786096
# predicted=6.785005, actual=6.782815
# predicted=6.783822, actual=6.781909
# predicted=6.780391, actual=6.769183
# predicted=6.772580, actual=6.766595
# predicted=6.768962, actual=6.749463
# predicted=6.750214, actual=6.768781
# predicted=6.767948, actual=6.785814
# predicted=6.783811, actual=6.798944
# predicted=6.796937, actual=6.793578
# predicted=6.791815, actual=6.789703
# predicted=6.791945, actual=6.810308
# predicted=6.811655, actual=6.831198
# predicted=6.831247, actual=6.829848
# predicted=6.828346, actual=6.829145
# predicted=6.828734, actual=6.811079
# predicted=6.814453, actual=6.812015
# predicted=6.814431, actual=6.811905
# predicted=6.812215, actual=6.807603
# predicted=6.807293, actual=6.811960
# predicted=6.810041, actual=6.808266
# predicted=6.808547, actual=6.821653
# predicted=6.820935, actual=6.813994
# predicted=6.813825, actual=6.814214
# predicted=6.814357, actual=6.809646
# predicted=6.809956, actual=6.796768
# predicted=6.798590, actual=6.815311
# predicted=6.814101, actual=6.817393
# predicted=6.817220, actual=6.824156
# predicted=6.822596, actual=6.824754
# predicted=6.823630, actual=6.825894
# predicted=6.827595, actual=6.828387
# predicted=6.828602, actual=6.832439
# predicted=6.832894, actual=6.844656
# predicted=6.844082, actual=6.835507
# predicted=6.835735, actual=6.843110
# predicted=6.842974, actual=6.853035
# predicted=6.853390, actual=6.859510
# predicted=6.859904, actual=6.846093
# predicted=6.845515, actual=6.835830
# predicted=6.837338, actual=6.839048
# predicted=6.840615, actual=6.827250
# predicted=6.828331, actual=6.826708
# predicted=6.825273, actual=6.837226
# predicted=6.836122, actual=6.835077
# predicted=6.835059, actual=6.835507
# predicted=6.834041, actual=6.838352
# predicted=6.838450, actual=6.826274
# predicted=6.827748, actual=6.812125
# predicted=6.812668, actual=6.804615
# predicted=6.805615, actual=6.809536
# predicted=6.809870, actual=6.813115
# predicted=6.811540, actual=6.793746
# predicted=6.792765, actual=6.791952
# predicted=6.791643, actual=6.778671
# predicted=6.780350, actual=6.794811
# predicted=6.794364, actual=6.803117
# predicted=6.800797, actual=6.801227
# predicted=6.800254, actual=6.811299
# predicted=6.809677, actual=6.792176
# predicted=6.794680, actual=6.805113
# predicted=6.805458, actual=6.803894
# predicted=6.804233, actual=6.801394
# predicted=6.801815, actual=6.778956
# predicted=6.778316, actual=6.768608
# predicted=6.770829, actual=6.772336
# predicted=6.772793, actual=6.758501
# predicted=6.758557, actual=6.764231
# predicted=6.761615, actual=6.757688
# predicted=6.757246, actual=6.772451
# predicted=6.771868, actual=6.763018
# predicted=6.762041, actual=6.762903
# predicted=6.763126, actual=6.767918
# predicted=6.767604, actual=6.764058
# predicted=6.765450, actual=6.768895
# predicted=6.767651, actual=6.770445
# predicted=6.770490, actual=6.769355
# predicted=6.769677, actual=6.751452
# predicted=6.751910, actual=6.705884
# predicted=6.708672, actual=6.713564
# predicted=6.714679, actual=6.723712
# predicted=6.723890, actual=6.742822
# predicted=6.738836, actual=6.754488
# predicted=6.748859, actual=6.761341
# predicted=6.761291, actual=6.749580
# predicted=6.751010, actual=6.748466
# predicted=6.750692, actual=6.755885
# predicted=6.757251, actual=6.757862
# predicted=6.758142, actual=6.749756
# predicted=6.748630, actual=6.746001
# predicted=6.746281, actual=6.763076
# predicted=6.763461, actual=6.769412
# predicted=6.768980, actual=6.767861
# predicted=6.766423, actual=6.760009
# predicted=6.760140, actual=6.747704
# predicted=6.750259, actual=6.750165
# predicted=6.751132, actual=6.732509
# predicted=6.733231, actual=6.733104
# predicted=6.732294, actual=6.733045
# predicted=6.732342, actual=6.752738
# predicted=6.751811, actual=6.750926
# predicted=6.748870, actual=6.752621
# predicted=6.752069, actual=6.749931
# predicted=6.750446, actual=6.766825
# predicted=6.768078, actual=6.765904
# predicted=6.765565, actual=6.770904
# predicted=6.770337, actual=6.752212
# predicted=6.752995, actual=6.736552
# predicted=6.739070, actual=6.719496
# predicted=6.721027, actual=6.721847
# predicted=6.722649, actual=6.716474
# predicted=6.714967, actual=6.714049
# predicted=6.712258, actual=6.728928
# predicted=6.726867, actual=6.729167
# predicted=6.729096, actual=6.748056
# predicted=6.746260, actual=6.757165
# predicted=6.756514, actual=6.751628
# predicted=6.752627, actual=6.748056
# predicted=6.748417, actual=6.743706
# predicted=6.746167, actual=6.750809
# predicted=6.751507, actual=6.746412
# predicted=6.745973, actual=6.776792
# predicted=6.774984, actual=6.784231
# predicted=6.783246, actual=6.785136
# predicted=6.784691, actual=6.774224
# predicted=6.774568, actual=6.766710
# predicted=6.770331, actual=6.782079
# predicted=6.782683, actual=6.791390
# predicted=6.790861, actual=6.801283
# predicted=6.799026, actual=6.803838
# predicted=6.802821, actual=6.798889
# predicted=6.800451, actual=6.793354
# predicted=6.794695, actual=6.796153
# predicted=6.797324, actual=6.786322
# predicted=6.786997, actual=6.807659
# predicted=6.806290, actual=6.817229
# predicted=6.816281, actual=6.818869
# predicted=6.818084, actual=6.822579
# predicted=6.821521, actual=6.821816
# predicted=6.824035, actual=6.826654
# predicted=6.827346, actual=6.827467
# predicted=6.827607, actual=6.826220
# predicted=6.826464, actual=6.831900
# predicted=6.831683, actual=6.843643
# predicted=6.843617, actual=6.839905
# predicted=6.839737, actual=6.841669
# predicted=6.841285, actual=6.845028
# predicted=6.845762, actual=6.850020
# predicted=6.850814, actual=6.851978
# predicted=6.851373, actual=6.852612
# predicted=6.852640, actual=6.845188
# predicted=6.845839, actual=6.852771
# predicted=6.853112, actual=6.860978
# predicted=6.860956, actual=6.856830
# predicted=6.856549, actual=6.860035
# predicted=6.859128, actual=6.846571
# predicted=6.848087, actual=6.845720
# predicted=6.846631, actual=6.857199
# predicted=6.856810, actual=6.854513
# predicted=6.854521, actual=6.856409
# predicted=6.854668, actual=6.855567
# predicted=6.855773, actual=6.841722
# predicted=6.843331, actual=6.843910
# predicted=6.843854, actual=6.853035
# predicted=6.853229, actual=6.848111
# predicted=6.847747, actual=6.846093
# predicted=6.844638, actual=6.843643
# predicted=6.844309, actual=6.843803
# predicted=6.844725, actual=6.841562
# predicted=6.841194, actual=6.849649
# predicted=6.849115, actual=6.845667
# predicted=6.845510, actual=6.831522
# predicted=6.831887, actual=6.839691
# predicted=6.839657, actual=6.827792
# predicted=6.829290, actual=6.830388
# predicted=6.829594, actual=6.829469
# predicted=6.828550, actual=6.830604
# predicted=6.831101, actual=6.828171
# predicted=6.827133, actual=6.832439
# predicted=6.832519, actual=6.841722
# predicted=6.841277, actual=6.843163
# predicted=6.842884, actual=6.840119
# predicted=6.839769, actual=6.848589
# predicted=6.848853, actual=6.850867
# predicted=6.851673, actual=6.864848
# predicted=6.864083, actual=6.866308
# predicted=6.865787, actual=6.852665
# predicted=6.853654, actual=6.854776
# predicted=6.855367, actual=6.851132
# predicted=6.853078, actual=6.850550
# predicted=6.850476, actual=6.862444
# predicted=6.860758, actual=6.866985
# predicted=6.866759, actual=6.875955
# predicted=6.874785, actual=6.882899
# predicted=6.882482, actual=6.880846
# predicted=6.881808, actual=6.903346
# predicted=6.902893, actual=6.904751
# predicted=6.905393, actual=6.899723
# predicted=6.899893, actual=6.902441
# predicted=6.902570, actual=6.904199
# predicted=6.906513, actual=6.897957
# predicted=6.898147, actual=6.903948
# predicted=6.903311, actual=6.906054
# predicted=6.906352, actual=6.902290
# predicted=6.902293, actual=6.894619
# predicted=6.894411, actual=6.872128
# predicted=6.873901, actual=6.877811
# predicted=6.878348, actual=6.883104
# predicted=6.882949, actual=6.887451
# predicted=6.885854, actual=6.880076
# predicted=6.877979, actual=6.871195
# predicted=6.872211, actual=6.859457
# predicted=6.860904, actual=6.866464
# predicted=6.866966, actual=6.863281
# predicted=6.862739, actual=6.858197
# predicted=6.857146, actual=6.857146
# predicted=6.856316, actual=6.861921
# predicted=6.862549, actual=6.858565
# predicted=6.858236, actual=6.874043
# predicted=6.872816, actual=6.876213
# predicted=6.875936, actual=6.877708
# predicted=6.877568, actual=6.877863
# predicted=6.877702, actual=6.874974
# predicted=6.876631, actual=6.865787
# predicted=6.866439, actual=6.865630
# predicted=6.866035, actual=6.875955
# predicted=6.875789, actual=6.874560
# predicted=6.873989, actual=6.875645
# predicted=6.874396, actual=6.864326
# predicted=6.864962, actual=6.872801
# predicted=6.873640, actual=6.877863
# predicted=6.877733, actual=6.885765
# predicted=6.885017, actual=6.898210
# predicted=6.896442, actual=6.897503
# predicted=6.898015, actual=6.895379
# predicted=6.895745, actual=6.900177
# predicted=6.901054, actual=6.897907
# predicted=6.899211, actual=6.894822
# predicted=6.894732, actual=6.866204
# predicted=6.867323, actual=6.856778
# predicted=6.858173, actual=6.863124
# predicted=6.863624, actual=6.855093
# predicted=6.854769, actual=6.849172
# predicted=6.846319, actual=6.848642
# predicted=6.848173, actual=6.858460
# predicted=6.858755, actual=6.846199
# predicted=6.845615, actual=6.835238
# predicted=6.834989, actual=6.846784
# predicted=6.847013, actual=6.851397
# predicted=6.852094, actual=6.844389
# predicted=6.842817, actual=6.857724
# predicted=6.856307, actual=6.859720
# predicted=6.860838, actual=6.860926
# predicted=6.860785, actual=6.857829
# predicted=6.857414, actual=6.857935
# predicted=6.859313, actual=6.860559
# predicted=6.860765, actual=6.849861
# predicted=6.850296, actual=6.841348
# predicted=6.841492, actual=6.838137
# predicted=6.838787, actual=6.835131
# predicted=6.835623, actual=6.820126
# predicted=6.819639, actual=6.811960
# predicted=6.811725, actual=6.816462
# predicted=6.816494, actual=6.829686
# predicted=6.828757, actual=6.819306
# predicted=6.817697, actual=6.817885
# predicted=6.817014, actual=6.824319
# predicted=6.825088, actual=6.839262
# predicted=6.839725, actual=6.851661
# predicted=6.849662, actual=6.854460
# predicted=6.853670, actual=6.841348
# predicted=6.842355, actual=6.843057
# predicted=6.844866, actual=6.844389
# predicted=6.845980, actual=6.839958
# predicted=6.840091, actual=6.847049
# predicted=6.845543, actual=6.841615
# predicted=6.842021, actual=6.826382
# predicted=6.826914, actual=6.825949
# predicted=6.826093, actual=6.830982
# predicted=6.831849, actual=6.827358
# predicted=6.826597, actual=6.827629
# predicted=6.826015, actual=6.834539
# predicted=6.834422, actual=6.830334
# predicted=6.830794, actual=6.845454
# predicted=6.844389, actual=6.840493
# predicted=6.840684, actual=6.852982
# predicted=6.852754, actual=6.898916
# predicted=6.896932, actual=6.921116
# predicted=6.920547, actual=6.911000
# predicted=6.909391, actual=6.906755
# predicted=6.908564, actual=6.918547
# predicted=6.923491, actual=6.924711
# predicted=6.926403, actual=6.923333
# predicted=6.921842, actual=6.921560
# predicted=6.921282, actual=6.940852
# predicted=6.941510, actual=6.944473
# predicted=6.944614, actual=6.928978
# predicted=6.928764, actual=6.923087
# predicted=6.923706, actual=6.914383
# predicted=6.917246, actual=6.912146
# predicted=6.912616, actual=6.902039
# predicted=6.901039, actual=6.902843
# predicted=6.902310, actual=6.910003
# predicted=6.909103, actual=6.913638
# predicted=6.912925, actual=6.904349
# predicted=6.903430, actual=6.907155
# predicted=6.907348, actual=6.889846
# predicted=6.891473, actual=6.891677
# predicted=6.892035, actual=6.894822
# predicted=6.894297, actual=6.901435
# predicted=6.901020, actual=6.889591
# predicted=6.888134, actual=6.887297
# predicted=6.887661, actual=6.900781
# predicted=6.901110, actual=6.898866
# predicted=6.899162, actual=6.911249
# predicted=6.909225, actual=6.917557
# predicted=6.917183, actual=6.916765
# predicted=6.917621, actual=6.889337
# predicted=6.890232, actual=6.894011
# predicted=6.895735, actual=6.906955
# predicted=6.907783, actual=6.936391
# predicted=6.934298, actual=6.906955
# predicted=6.904460, actual=6.917656
# predicted=6.917678, actual=6.924022
# predicted=6.926335, actual=6.924514
# predicted=6.926335, actual=6.935516
# predicted=6.932214, actual=6.932594
# predicted=6.933663, actual=6.931472
# predicted=6.931888, actual=6.930983
# predicted=6.931385, actual=6.933813
# predicted=6.934775, actual=6.929664
# predicted=6.929467, actual=6.896998
# predicted=6.898119, actual=6.918398
# predicted=6.918358, actual=6.903848
# predicted=6.905149, actual=6.927362
# predicted=6.924981, actual=6.930201
# predicted=6.927285, actual=6.924268
# predicted=6.925569, actual=6.930739
# predicted=6.929539, actual=6.950575
# predicted=6.952234, actual=6.955354
# predicted=6.954755, actual=6.958401
# predicted=6.957149, actual=6.968568
# predicted=6.969027, actual=6.967250
# predicted=6.969080, actual=6.960537
# predicted=6.961061, actual=6.966213
# predicted=6.966669, actual=6.952920
# predicted=6.954505, actual=6.958638
# predicted=6.958223, actual=6.991085
# predicted=6.989550, actual=6.996087
# predicted=6.995386, actual=6.992142
# predicted=6.990054, actual=7.000426
# predicted=7.001262, actual=6.992050
# predicted=6.995616, actual=6.983512
# predicted=6.984177, actual=6.981795
# predicted=6.982051, actual=6.988367
# predicted=6.989034, actual=6.988044
# predicted=6.986990, actual=6.985040
# predicted=6.984108, actual=6.985827
# predicted=6.985829, actual=6.988367
# predicted=6.988975, actual=6.988874
# predicted=6.988690, actual=6.986382
# predicted=6.986117, actual=6.994208
# predicted=6.994067, actual=6.988136
# predicted=6.988553, actual=6.988183
# predicted=6.988071, actual=6.996956
# predicted=6.996703, actual=7.002747
# predicted=7.002990, actual=6.985827
# predicted=6.985526, actual=6.982120
# predicted=6.982616, actual=6.983651
# predicted=6.985126, actual=6.987860
# predicted=6.987994, actual=6.991315
# predicted=6.989333, actual=7.009454
# predicted=7.008227, actual=7.011575
# predicted=7.011270, actual=7.007058
# predicted=7.007141, actual=6.983187
# predicted=6.984829, actual=6.972653
# predicted=6.975454, actual=6.961722
# predicted=6.963162, actual=6.972841
# predicted=6.972048, actual=6.990855
# predicted=6.987789, actual=6.994162
# predicted=6.992128, actual=7.000107
# predicted=6.998436, actual=7.015488
# predicted=7.016096, actual=7.010222
# predicted=7.011722, actual=7.056305
# predicted=7.054642, actual=7.047865
# predicted=7.048368, actual=7.038301
# predicted=7.038859, actual=7.040580
# predicted=7.041278, actual=7.044295
# predicted=7.048671, actual=7.031653
# predicted=7.031010, actual=7.023759
# predicted=7.023328, actual=7.017237
# predicted=7.018295, actual=7.018447
# predicted=7.018866, actual=7.028201
# predicted=7.026639, actual=7.021575
# predicted=7.020730, actual=7.024960
# predicted=7.024071, actual=7.030902
# predicted=7.031104, actual=7.030415
# predicted=7.031028, actual=7.021932
# predicted=7.021528, actual=7.013106
# predicted=7.014058, actual=7.033947
# predicted=7.034132, actual=7.031697
# predicted=7.031429, actual=7.029796
# predicted=7.028324, actual=7.027270
# predicted=7.027026, actual=7.004882
# predicted=7.007807, actual=7.015443
# predicted=7.015292, actual=7.022021
# predicted=7.021983, actual=7.056175
# predicted=7.053758, actual=6.976768
# predicted=6.977292, actual=7.010898
# predicted=7.010929, actual=7.012476
# predicted=7.015577, actual=7.022601
# predicted=7.022586, actual=7.024471
# predicted=7.017290, actual=7.019475
# predicted=7.022633, actual=7.020682
# predicted=7.021026, actual=7.009725
# predicted=7.011364, actual=7.008189
# predicted=7.008497, actual=7.023625
# predicted=7.022848, actual=7.042679
# predicted=7.041464, actual=7.053413
# predicted=7.051014, actual=7.055011
# predicted=7.054311, actual=7.064844
# predicted=7.065903, actual=7.088367
# predicted=7.089147, actual=7.104965
# predicted=7.104577, actual=7.106524
# predicted=7.105799, actual=7.089743
# predicted=7.091381, actual=7.099903
# predicted=7.102332, actual=7.082213
# predicted=7.084966, actual=7.091409
# predicted=7.090773, actual=7.117206
# predicted=7.115069, actual=7.117530
# predicted=7.117358, actual=7.118867
# predicted=7.116494, actual=7.129498
# predicted=7.130416, actual=7.125444
# predicted=7.127849, actual=7.121616
# predicted=7.121587, actual=7.117124
# predicted=7.117868, actual=7.114729
# predicted=7.115958, actual=7.122786
# predicted=7.122148, actual=7.131139
# predicted=7.130243, actual=7.129818
# predicted=7.128997, actual=7.123794
# predicted=7.123763, actual=7.112124
# predicted=7.113726, actual=7.109062
# predicted=7.110366, actual=7.088325
# predicted=7.089401, actual=7.096059
# predicted=7.095372, actual=7.100605
# predicted=7.099748, actual=7.097921
# predicted=7.096999, actual=7.102417
# predicted=7.100322, actual=7.098458
# predicted=7.099460, actual=7.087198
# predicted=7.087999, actual=7.066979
# predicted=7.068024, actual=7.062063
# predicted=7.063333, actual=7.066851
# predicted=7.066761, actual=7.060133
# predicted=7.059015, actual=7.066126
# predicted=7.063829, actual=7.067149
# predicted=7.066840, actual=7.063348
# predicted=7.063624, actual=7.057597
# predicted=7.057371, actual=7.079395
# predicted=7.079250, actual=7.069789
# predicted=7.070015, actual=7.072803
# predicted=7.071690, actual=7.068896
# predicted=7.069218, actual=7.082633
# predicted=7.083849, actual=7.092989
# predicted=7.091570, actual=7.101099
# predicted=7.100333, actual=7.111798
# predicted=7.110783, actual=7.109757
# predicted=7.110913, actual=7.108162
# predicted=7.109075, actual=7.114119
# predicted=7.114936, actual=7.114729
# predicted=7.115612, actual=7.129057
# predicted=7.128012, actual=7.119919
# predicted=7.120014, actual=7.119595
# predicted=7.119896, actual=7.096846
# predicted=7.098487, actual=7.118826
# predicted=7.119410, actual=7.120687
# predicted=7.120083, actual=7.119919
# predicted=7.118712, actual=7.132617
# predicted=7.130317, actual=7.131179
# predicted=7.133156, actual=7.141126
# predicted=7.140470, actual=7.145275
# predicted=7.145156, actual=7.161118
# predicted=7.161205, actual=7.163947
# predicted=7.163496, actual=7.199267
# predicted=7.198207, actual=7.186825
# predicted=7.187449, actual=7.184326
# predicted=7.185084, actual=7.188299
# predicted=7.189571, actual=7.192220
# predicted=7.195126, actual=7.175184
# predicted=7.174536, actual=7.149132
# predicted=7.150286, actual=7.150231
# predicted=7.151607, actual=7.135966
# predicted=7.137379, actual=7.122665
# predicted=7.121266, actual=7.117935
# predicted=7.116368, actual=7.120121
# predicted=7.120293, actual=7.126208
# predicted=7.124422, actual=7.125685
# predicted=7.124193, actual=7.109062
# predicted=7.109211, actual=7.116191
# predicted=7.116506, actual=7.135289
# predicted=7.135410, actual=7.125404
# predicted=7.124880, actual=7.115785
# predicted=7.114390, actual=7.142432
# predicted=7.142821, actual=7.138113
# predicted=7.139686, actual=7.144802
# predicted=7.142645, actual=7.132178
# predicted=7.132460, actual=7.133096
# predicted=7.135461, actual=7.135249
# predicted=7.135268, actual=7.164604
# predicted=7.163576, actual=7.194324
# predicted=7.191326, actual=7.179422
# predicted=7.178787, actual=7.164140
# predicted=7.164999, actual=7.163792
# predicted=7.167964, actual=7.152425
# predicted=7.155838, actual=7.167578
# predicted=7.165410, actual=7.171926
# predicted=7.170391, actual=7.153599
# predicted=7.153568, actual=7.137954
# Test RMSE: 0.012

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Calculate metrics
mae = mean_absolute_error(test_slice, predictions)
mse = mean_squared_error(test_slice, predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((test_slice - predictions) / test_slice)) * 100
r2 = r2_score(test_slice, predictions)

print(f'Mean Absolute Error (MAE): {mae:.3f}')
print(f'Mean Squared Error (MSE): {mse:.3f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.3f}')
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
print(f'R-squared (R²): {r2:.3f}')
# Out:
# Mean Absolute Error (MAE): 0.009
# Mean Squared Error (MSE): 0.000
# Root Mean Squared Error (RMSE): 0.012
# Mean Absolute Percentage Error (MAPE): 0.13%
# R-squared (R²): 0.992

# %%
# from statsmodels.tsa.arima.model import ARIMA
# from sklearn.metrics import mean_squared_error
# import numpy as np
# import matplotlib.pyplot as plt

# x = y.values
# train_size = int(len(x) * 0.7)
# train, test = x[0:train_size], x[train_size:]
# history = [x for x in train]
# predictions = []

# for t in range(len(test)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()  # No disp argument
#     output = model_fit.forecast(steps=1)
#     yhat = output[0]
#     predictions.append(yhat)
#     obs = test[t]
#     history.append(obs)
#     print('predicted=%f, actual=%f' % (yhat, obs))

# error = mean_squared_error(test, predictions)
# print('Test RMSE: %.3f' % np.sqrt(error))

# plt.plot(test, label='Actual')
# plt.plot(predictions, color='red', label='Predicted')
# plt.legend()
# plt.show()

# %% [markdown]
# # 5. Making the predictions

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Assume y is your log-transformed time series data and already loaded
x_log = y.values

# Fit the ARIMA model on the log-transformed data
model = ARIMA(x_log, order=(5,1,0))  # p, d, q
model_fit = model.fit()

# Forecast the next value in the log-transformed scale
forecast_log = model_fit.forecast(steps=1) # next day
forecast_log_value = forecast_log[0]

# Reverse the logarithmic transformation to get the actual price
forecast_value = np.exp(forecast_log_value)

# Get tomorrow's date
today = datetime.now()
tomorrow = today + timedelta(days=1)
tomorrow_date_str = tomorrow.strftime('%Y-%m-%d')  # Format date as YYYY-MM-DD

print(f'The predicted stock price for {tomorrow_date_str} is: {forecast_value:.2f}')
# Out:
# The predicted stock price for 2024-11-13 is: 1259.02

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assume y is your log-transformed time series data and already loaded
x_log = y.values

# Fit the ARIMA model on the log-transformed data
model = ARIMA(x_log, order=(5,1,0))  # p, d, q
model_fit = model.fit()

# Forecast the next 10 days in the log-transformed scale
forecast_log = model_fit.forecast(steps=10)
forecast_log_values = forecast_log

# Reverse the logarithmic transformation to get the actual prices
forecast_values = np.exp(forecast_log_values)

# Generate dates for the next 10 days
last_date = pd.to_datetime('today')  # Adjust if you have a specific end date
dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=10, freq='D')

# Create a DataFrame to display results
forecast_df = pd.DataFrame({
    'Date': dates,
    'Forecasted Price': forecast_values
})

print(forecast_df)

# Optional: Plot the forecasted prices
plt.figure(figsize=(12, 6))
plt.plot(dates, forecast_values, marker='o', linestyle='-', color='red', label='Forecasted Prices')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Forecasted Stock Prices for the Next 10 Days')
plt.legend()
plt.grid()
plt.show()
# Out:
#                         Date  Forecasted Price
# 0 2024-11-13 23:24:40.310977       1259.016302
# 1 2024-11-14 23:24:40.310977       1262.000787
# 2 2024-11-15 23:24:40.310977       1262.502536
# 3 2024-11-16 23:24:40.310977       1259.828782
# 4 2024-11-17 23:24:40.310977       1257.998996
# 5 2024-11-18 23:24:40.310977       1258.190432
# 6 2024-11-19 23:24:40.310977       1258.589169
# 7 2024-11-20 23:24:40.310977       1258.615074
# 8 2024-11-21 23:24:40.310977       1258.311122
# 9 2024-11-22 23:24:40.310977       1258.143994

# %%
# # Example data setup (ensure y is defined and contains your time series data)
# x = y.values  # y is your data series
# train_size = int(len(x) * 0.6)  # 60% for training
# validation_size = int(len(x) * 0.2)  # 20% for validation

# # Split the data into training, validation, and testing
# train = x[:train_size]
# validation = x[train_size:train_size + validation_size]
# test = x[train_size + validation_size:]

# history = list(train)  # Use list() to ensure history is a list
# validation_predictions = []
# test_predictions = []

# # 1. Validation predictions
# for t in range(len(validation)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()
#     output = model_fit.forecast(steps=1)
#     yhat = output[0]
#     validation_predictions.append(yhat)
#     obs = validation[t]
#     history.append(obs)
#     print(f'Validation - predicted={yhat:.6f}, actual={obs:.6f}')

# # 2. Test predictions
# for t in range(len(test)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()
#     output = model_fit.forecast(steps=1)
#     yhat = output[0]
#     test_predictions.append(yhat)
#     obs = test[t]
#     history.append(obs)
#     print(f'Test - predicted={yhat:.6f}, actual={obs:.6f}')

# # Calculate RMSE for validation and test sets
# validation_error = mean_squared_error(validation, validation_predictions)
# test_error = mean_squared_error(test, test_predictions)

# print(f'Validation RMSE: {np.sqrt(validation_error):.3f}')
# print(f'Test RMSE: {np.sqrt(test_error):.3f}')

# # Plot the results
# plt.figure(figsize=(14, 7))

# # Plot training data
# plt.plot(range(len(train)), train, label='Training Data', color='green')

# # Plot validation predictions and actual validation data
# plt.plot(range(len(train), len(train) + len(validation)), validation, label='Validation Data', color='blue')
# plt.plot(range(len(train), len(train) + len(validation)), validation_predictions, label='Validation Predictions', linestyle='--', color='orange')

# # Plot test predictions and actual test data
# plt.plot(range(len(train) + len(validation), len(x)), test, label='Test Data', color='blue')
# plt.plot(range(len(train) + len(validation), len(x)), test_predictions, label='Test Predictions', linestyle='--', color='red')

# plt.xlabel('Time')
# plt.ylabel('Stock Price')
# plt.title('Training, Validation, and Test Data vs Predictions')
# plt.legend()
# plt.show()

# %% [markdown]
# 2. SARIMA

# %%
warnings.filterwarnings("ignore", message="Maximum Likelihood optimization failed to converge")

x = y.values
train_size = int(len(x) * 0.7)
train, test = x[0:train_size], x[train_size:]

history = list(train)  # Use list() to ensure history is a list
predictions = []

# Define SARIMA parameters
# Adjust the (p, d, q) and (P, D, Q, s) parameters based on your data
seasonal_period = 12  # Example: monthly data with yearly seasonality
num_predictions = 20
cnt = 0

for t in range(len(test)):
    if cnt == num_predictions:
        break
    model = SARIMAX(history, order=(5,1,0), seasonal_order=(1,1,1,seasonal_period))
    model_fit = model.fit(disp=False)  # No disp argument
    output = model_fit.forecast(steps=1)
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'predicted={yhat:.6f}, actual={obs:.6f}')
    cnt += 1

# Ensure predictions and test have the same length
if len(predictions) != num_predictions:
    raise ValueError(f"Predictions length ({len(predictions)}) does not match expected number ({num_predictions})")

# Slice the test set to match the length of predictions
test_slice = test[:num_predictions]

# Calculate error
error = mean_squared_error(test_slice, predictions)
print(f'Test RMSE: {np.sqrt(error):.3f}')

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(test_slice, label='Actual', color='blue')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Actual vs Predicted Stock Prices')
plt.legend()
plt.show()
# Out:
# predicted=6.557796, actual=6.561314
# predicted=6.562655, actual=6.556636
# predicted=6.555229, actual=6.579390
# predicted=6.579116, actual=6.578487
# predicted=6.576467, actual=6.587481
# predicted=6.588783, actual=6.609349
# predicted=6.606324, actual=6.627644
# predicted=6.632875, actual=6.645741
# predicted=6.650348, actual=6.633187
# predicted=6.636709, actual=6.624331
# predicted=6.626362, actual=6.623268
# predicted=6.624828, actual=6.621672
# predicted=6.623709, actual=6.648985
# predicted=6.645333, actual=6.660127
# predicted=6.658398, actual=6.663260
# predicted=6.663418, actual=6.666957
# predicted=6.666843, actual=6.684674
# predicted=6.689314, actual=6.685736
# predicted=6.686605, actual=6.679976
# predicted=6.684837, actual=6.685237
# Test RMSE: 0.013

# %%
# Calculate metrics
mae = mean_absolute_error(test_slice, predictions)
mse = mean_squared_error(test_slice, predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((test_slice - predictions) / test_slice)) * 100
r2 = r2_score(test_slice, predictions)

print(f'Mean Absolute Error (MAE): {mae:.3f}')
print(f'Mean Squared Error (MSE): {mse:.3f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.3f}')
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
print(f'R-squared (R²): {r2:.3f}')
# Out:
# Mean Absolute Error (MAE): 0.011
# Mean Squared Error (MSE): 0.000
# Root Mean Squared Error (RMSE): 0.013
# Mean Absolute Percentage Error (MAPE): 0.16%
# R-squared (R²): 0.894

# %%
model = SARIMAX(x_log, order=(5,1,0), seasonal_order=(1,1,1,12))  # Example parameters
model_fit = model.fit(disp=False)

# Forecast the next value in the log-transformed scale
forecast_log = model_fit.forecast(steps=1) # next day
forecast_log_value = forecast_log[0]

# Reverse the logarithmic transformation to get the actual price
forecast_value = np.exp(forecast_log_value)

# Get tomorrow's date
today = datetime.now()
tomorrow = today + timedelta(days=1)
tomorrow_date_str = tomorrow.strftime('%Y-%m-%d')  # Format date as YYYY-MM-DD

print(f'The predicted stock price for {tomorrow_date_str} is: {forecast_value:.2f}')
# Out:
# The predicted stock price for 2024-11-13 is: 1263.10

# %%
# Assume y is your log-transformed time series data and already loaded
x_log = y.values

# Define the SARIMA model
# Example parameters; adjust these based on your data and seasonal period
model = SARIMAX(x_log, order=(5,1,0), seasonal_order=(1,1,1,12))  # Adjust parameters as needed
model_fit = model.fit(disp=False)

# Forecast the next 10 days in the log-transformed scale
forecast_log = model_fit.forecast(steps=10)
forecast_log_values = forecast_log

# Reverse the logarithmic transformation to get the actual prices
forecast_values = np.exp(forecast_log_values)

# Generate dates for the next 10 days
today = datetime.now()
dates = [today + timedelta(days=i+1) for i in range(10)] 
dates_str = [date.strftime('%Y-%m-%d') for date in dates]

# Create a DataFrame to display results
forecast_df = pd.DataFrame({
    'Date': dates_str,
    'Forecasted Price': forecast_values
})

print(forecast_df)

# Optional: Plot the forecasted prices
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(dates, forecast_values, marker='o', linestyle='-', color='red', label='Forecasted Prices')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Forecasted Stock Prices for the Next 10 Days')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
#          Date  Forecasted Price
# 0  2024-11-13       1263.104667
# 1  2024-11-14       1271.346446
# 2  2024-11-15       1275.175054
# 3  2024-11-16       1273.970438
# 4  2024-11-17       1270.530147
# 5  2024-11-18       1269.978358
# 6  2024-11-19       1270.509509
# 7  2024-11-20       1269.782032
# 8  2024-11-21       1272.412588
# 9  2024-11-22       1272.248092

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from statsmodels.tsa.arima.model import ARIMA

# # Assume y is your log-transformed time series data and already loaded
# x_log = y.values
# train_size = int(len(x_log) * 0.7)
# train, test = x_log[0:train_size], x_log[train_size:]
# test_actual = np.exp(test)  # Convert test data back to original scale
# history = [x for x in train]
# predictions = []

# # Forecasting the test period
# for t in range(len(test)):
#     model = ARIMA(history, order=(5,1,0))  # p, d, q
#     model_fit = model.fit()
#     output = model_fit.forecast(steps=1)
#     yhat_log = output[0]
#     yhat = np.exp(yhat_log)  # Convert forecasted log value back to original scale
#     predictions.append(yhat)
#     obs = np.exp(test[t])  # Ensure actual test values are in original scale
#     history.append(test[t])
#     # print('predicted=%f, actual=%f' % (yhat, obs))

# # Convert predictions to a numpy array for easy plotting
# predictions = np.array(predictions)

# # Plot actual vs predicted prices
# plt.figure(figsize=(12, 6))
# plt.plot(test_actual, label='Actual Prices', color='blue')
# plt.plot(predictions, color='red', label='Predicted Prices')
# plt.xlabel('Time')
# plt.ylabel('Stock Price')
# plt.title('Actual vs Predicted Stock Prices')
# plt.legend()
# plt.show()
