# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import StandardScaler
from datetime import datetime, timedelta
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# # 1. Data Collection

# %%
def display_tickers(tickers):
    print("\nNifty 50 Company Ticker Symbols (Yahoo Finance Format):")
    print(*tickers, sep=", ")

# %%
tickers_df = pd.read_csv("nifty50_tickers.csv")
tickers = tickers_df['Ticker'].tolist()
display_tickers(tickers)
# Out:
# Nifty 50 Company Ticker Symbols (Yahoo Finance Format):
# ADANIENT.NS, ADANIPORTS.NS, APOLLOHOSP.NS, ASIANPAINT.NS, AXISBANK.NS, BAJAJ-AUTO.NS, BAJFINANCE.NS, BAJAJFINSV.NS, BEL.NS, BPCL.NS, BHARTIARTL.NS, BRITANNIA.NS, CIPLA.NS, COALINDIA.NS, DRREDDY.NS, EICHERMOT.NS, GRASIM.NS, HCLTECH.NS, HDFCBANK.NS, HDFCLIFE.NS, HEROMOTOCO.NS, HINDALCO.NS, HINDUNILVR.NS, ICICIBANK.NS, INDUSINDBK.NS, INFY.NS, ITC.NS, JSWSTEEL.NS, KOTAKBANK.NS, LT.NS, M&M.NS, MARUTI.NS, NESTLEIND.NS, NTPC.NS, ONGC.NS, POWERGRID.NS, RELIANCE.NS, SBILIFE.NS, SHRIRAMFIN.NS, SBIN.NS, SUNPHARMA.NS, TCS.NS, TATACONSUM.NS, TATAMOTORS.NS, TATASTEEL.NS, TECHM.NS, TITAN.NS, TRENT.NS, ULTRACEMCO.NS, WIPRO.NS

# %%
# Ask user for a company
user_input = input("\nPlease enter the name of the company you want to download data for: ").strip()

# Find the corresponding ticker (assumed tickers_df is already defined)
matched_ticker = None
for ticker in tickers_df['Ticker']:
    if ticker.split('.')[0].lower() == user_input.lower():
        matched_ticker = ticker
        break

# Download the data if ticker is found
if matched_ticker:
    folder = 'CSVfiles'  # Ensure the folder name is defined
    try:
        if not os.path.exists(folder):
            os.makedirs(folder)
        
        # Get yesterday's date
        yesterday = (datetime.now() - timedelta(1)).strftime('%Y-%m-%d')
        
        # Download the stock data from 2017 to yesterday's date
        data = yf.download(matched_ticker, start='2017-01-01', end=yesterday)
        data.fillna(0, inplace=True)
        data
        
        # Save to CSV
        filename = os.path.join(folder, f"{matched_ticker}.csv")
        data.to_csv(filename)
        print(f"\nData for {matched_ticker} saved to {filename}")

    except Exception as e:
        print(f"An error occurred while downloading data for {matched_ticker}: {e}")

else:
    print("Company not found in Nifty 50 list.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data for HDFCBANK.NS saved to CSVfiles\HDFCBANK.NS.csv

# %%
yesterday = (datetime.now() - timedelta(1)).strftime('%Y-%m-%d')

stock_data = yf.download(f'{user_input}.NS', start='2017-01-01', end=yesterday)
stock_data.fillna(0, inplace=True)
df = pd.DataFrame(stock_data)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-01-02   604.724976   605.049988   596.025024   598.549988   562.424561
# 2017-01-03   600.400024   600.974976   592.875000   594.950012   559.041870
# 2017-01-04   594.924988   596.000000   591.900024   592.750000   556.974548
# 2017-01-05   594.500000   597.250000   591.549988   593.099976   557.303467
# 2017-01-06   595.049988   599.200012   594.099976   596.825012   560.803711
# ...                 ...          ...          ...          ...          ...
# 2024-11-04  1745.000000  1745.000000  1710.900024  1714.099976  1714.099976
# 2024-11-05  1703.000000  1762.699951  1697.900024  1757.849976  1757.849976
# 2024-11-06  1771.500000  1771.500000  1745.349976  1755.250000  1755.250000
# 2024-11-07  1744.300049  1760.949951  1738.000000  1746.550049  1746.550049
# 2024-11-08  1752.000000  1761.800049  1745.849976  1754.449951  1754.449951
#
#               Volume
# Date
# 2017-01-02   1854328
# 2017-01-03   1923750
# 2017-01-04   3483560
# 2017-01-05   3388192
# 2017-01-06   2762630
# ...              ...
# 2024-11-04  14044624
# 2024-11-05  22116203
# 2024-11-06  13893955
# 2024-11-07   9447728
# 2024-11-08   9951493
#
# [1941 rows x 6 columns]

# %% [markdown]
# # 2. Data Preprocessing

# %%
# This applies the natural logarithm (logarithm with base e) to the Close column of the DataFrame df.
# The reason for taking the logarithm of the closing prices is to stabilize the variance,
#  which can help in time series modeling (especially when working with non-stationary data). 
# Log transformations can reduce the effect of large fluctuations and make the data more stationary.


y = np.log(df["Close"])
y.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
y.asfreq("D")[:15]
# Out:
# Date
# 2017-01-02    6.394510
# 2017-01-03    6.388477
# 2017-01-04    6.384773
# 2017-01-05    6.385363
# 2017-01-06    6.391624
# 2017-01-07         NaN
# 2017-01-08         NaN
# 2017-01-09    6.392922
# 2017-01-10    6.408817
# 2017-01-11    6.424869
# 2017-01-12    6.425679
# 2017-01-13    6.423653
# 2017-01-14         NaN
# 2017-01-15         NaN
# 2017-01-16    6.435870
# Freq: D, Name: Close, dtype: float64

# %% [markdown]
# Let's impute the missing data by forward fill using asfreq method.

# %%
y.asfreq("D", method="ffill")[:15]   # used to forward fill missing values.
# Out:
# Date
# 2017-01-02    6.394510
# 2017-01-03    6.388477
# 2017-01-04    6.384773
# 2017-01-05    6.385363
# 2017-01-06    6.391624
# 2017-01-07    6.391624
# 2017-01-08    6.391624
# 2017-01-09    6.392922
# 2017-01-10    6.408817
# 2017-01-11    6.424869
# 2017-01-12    6.425679
# 2017-01-13    6.423653
# 2017-01-14    6.423653
# 2017-01-15    6.423653
# 2017-01-16    6.435870
# Freq: D, Name: Close, dtype: float64

# %% [markdown]
# Formal of way of test for stationarity. Since the p-value of Augmented Dickey Fullter test is > 0.05,
# we can say that there is not sufficient proof that the time series is stationary.
# Loosely speaking, it is non-stationary. We need further transformation to make data stationary.
# Populary method for making data stationary will be to take "difference".
# Taking difference by lag one, we see the p-val for Dickey Fuller test is < 0.05.
# So we conclude, diff 1 will made the data stationary.

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(prices):
    result=adfuller(prices)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

        
adfuller_test(df['Close'])
# Out:
# ADF Test Statistic : -1.733861345150783
# p-value : 0.4137559187140354
# #Lags Used : 19
# Number of Observations Used : 1921
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
result = adfuller(y.diff(periods=1).dropna())

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -9.986201
# p-value: 0.000000

# %%
y.diff(periods=1).plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
y
# Out:
# Date
# 2017-01-02    6.394510
# 2017-01-03    6.388477
# 2017-01-04    6.384773
# 2017-01-05    6.385363
# 2017-01-06    6.391624
#                 ...
# 2024-11-04    7.446643
# 2024-11-05    7.471847
# 2024-11-06    7.470367
# 2024-11-07    7.465398
# 2024-11-08    7.469911
# Name: Close, Length: 1941, dtype: float64

# %%
y = y.dropna()

# %% [markdown]
# # 3. Finding the p,d,q

# %% [markdown]
# Identification of an AR model is often best done with the PACF.
#
# For an AR model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model. By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
# Identification of an MA model is often best done with the ACF rather than the PACF. p,d,q
#
# For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner. A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
# p AR model lags d differencing q MA lags

# %%
# Plot ACF and PACF for differenced data

plt.figure(figsize=(12, 8))

# ACF plot
plt.subplot(211)
plot_acf(y.diff(periods=1).dropna(), ax=plt.gca(), lags=50)
plt.title('ACF Plot')


# PACF plot
plt.subplot(212)
plot_pacf(y.diff(periods=1).dropna(), ax=plt.gca(), lags=50)
plt.title('PACF Plot')
plt.show()
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima.model import ARIMA


# fit model
# model = ARIMA(y, order=(5, 1, 0))  # p, d, q
model = ARIMA(y, order=(5, 1, 0))
model_fit = model.fit()

#print(model_fit.summary())

import pandas as pd
import matplotlib.pyplot as plt

# Residual density refers to the distribution of residuals from a statistical model. 
# Residuals are the differences between the observed values and the values predicted by the model.

# Purpose: By examining the residual density, you can assess whether residuals are normally distributed 
# and identify any patterns or anomalies that suggest problems with the model.

# plot residual erros
residuals = pd.DataFrame(model_fit.resid)
# residuals.plot()
# residuals.plot(kind='kde')
# print(residuals.describe())

# Plot residuals density
residuals.plot(kind='kde')
plt.title('Residuals Density')
plt.show()

# Print residuals description
print(residuals.describe())
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                  0
# count  1941.000000
# mean      0.003827
# std       0.145911
# min      -0.131273
# 25%      -0.006509
# 50%       0.000605
# 75%       0.007424
# max       6.394510

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(y, order=(1, 1, 1))
model_fit = model.fit()

#print(model_fit.summary())

import pandas as pd
import matplotlib.pyplot as plt

# Plot residuals density
residuals.plot(kind='kde')
plt.title('Residuals Density')
plt.show()

# Print residuals description
print(residuals.describe())
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\ronak\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                  0
# count  1941.000000
# mean      0.003827
# std       0.145911
# min      -0.131273
# 25%      -0.006509
# 50%       0.000605
# 75%       0.007424
# max       6.394510

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1941
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                5379.025
# Date:                Tue, 12 Nov 2024   AIC                         -10752.051
# Time:                        20:25:32   BIC                         -10735.340
# Sample:                             0   HQIC                        -10745.905
#                                - 1941
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1899      0.281     -0.676      0.499      -0.741       0.361
# ma.L1          0.2246      0.277      0.811      0.417      -0.318       0.767
# sigma2         0.0002   3.06e-06     74.622      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              9123.81
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -0.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.endog
# Out:
# array([[6.39451004],
#        [6.38847739],
#        [6.38477272],
#        ...,
#        [7.47036658],
#        [7.46539772],
#        [7.46991067]])

# %% [markdown]
# # 4 . Data Splitting and Model Fitting

# %% [markdown]
# Spliting the data
# we split the normalized data into training and testing sets :
#
# 70% for training,
# 30% for testing.

# %%
import warnings
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Ignore specific warnings
warnings.filterwarnings("ignore", message="Maximum Likelihood optimization failed to converge")

# Example data setup (ensure y is defined and contains your data)
x = y.values
train_size = int(len(x) * 0.7)
train, test = x[0:train_size], x[train_size:]

history = list(train)  # Use list() to ensure history is a list
predictions = []

# # Use test samples
num_predictions = len(test)
cnt = 0

for t in range(len(test)):
    if cnt == num_predictions:
        break
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()  # No disp argument
    output = model_fit.forecast(steps=1)
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'predicted={yhat:.6f}, actual={obs:.6f}')
    cnt += 1

# Ensure predictions and test have the same length
if len(predictions) != num_predictions:
    raise ValueError(f"Predictions length ({len(predictions)}) does not match expected number ({num_predictions})")

# Slice the test set to match the length of predictions
test_slice = test[:num_predictions]

# Calculate error
error = mean_squared_error(test_slice, predictions)
print(f'Test RMSE: {np.sqrt(error):.3f}')

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(test_slice, label='Actual', color='blue')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Actual vs Predicted Stock Prices')
plt.legend()
plt.show()
# Out:
# predicted=7.204565, actual=7.206377
# predicted=7.207639, actual=7.210634
# predicted=7.210438, actual=7.212036
# predicted=7.211228, actual=7.209784
# predicted=7.209525, actual=7.223478
# predicted=7.224535, actual=7.241223
# predicted=7.241348, actual=7.242154
# predicted=7.240603, actual=7.248611
# predicted=7.248850, actual=7.238353
# predicted=7.238887, actual=7.213658
# predicted=7.214210, actual=7.208637
# predicted=7.210727, actual=7.216746
# predicted=7.217999, actual=7.206043
# predicted=7.203584, actual=7.206414
# predicted=7.205472, actual=7.218946
# predicted=7.219724, actual=7.215791
# predicted=7.214774, actual=7.238856
# predicted=7.239253, actual=7.241796
# predicted=7.240791, actual=7.239753
# predicted=7.239553, actual=7.247365
# predicted=7.248448, actual=7.256191
# predicted=7.257464, actual=7.268362
# predicted=7.268201, actual=7.276660
# predicted=7.276140, actual=7.265605
# predicted=7.265018, actual=7.267944
# predicted=7.269628, actual=7.266758
# predicted=7.267750, actual=7.263365
# predicted=7.263320, actual=7.287595
# predicted=7.288385, actual=7.290498
# predicted=7.289024, actual=7.303641
# predicted=7.303342, actual=7.303271
# predicted=7.302924, actual=7.314653
# predicted=7.316408, actual=7.319799
# predicted=7.319870, actual=7.320990
# predicted=7.321190, actual=7.308576
# predicted=7.308231, actual=7.293256
# predicted=7.294262, actual=7.290156
# predicted=7.291697, actual=7.294955
# predicted=7.295327, actual=7.289508
# predicted=7.287725, actual=7.289679
# predicted=7.288998, actual=7.271982
# predicted=7.271284, actual=7.303911
# predicted=7.306615, actual=7.294479
# predicted=7.291914, actual=7.303507
# predicted=7.303186, actual=7.309915
# predicted=7.309927, actual=7.306095
# predicted=7.306775, actual=7.301350
# predicted=7.301077, actual=7.311619
# predicted=7.313204, actual=7.312287
# predicted=7.311919, actual=7.308911
# predicted=7.308117, actual=7.321916
# predicted=7.322790, actual=7.332140
# predicted=7.332331, actual=7.326926
# predicted=7.325634, actual=7.308375
# predicted=7.308036, actual=7.314952
# predicted=7.317751, actual=7.326926
# predicted=7.327732, actual=7.325379
# predicted=7.323338, actual=7.303843
# predicted=7.302005, actual=7.276660
# predicted=7.277886, actual=7.263084
# predicted=7.265502, actual=7.254072
# predicted=7.254297, actual=7.236735
# predicted=7.234567, actual=7.231540
# predicted=7.230606, actual=7.259362
# predicted=7.260266, actual=7.253612
# predicted=7.250341, actual=7.281386
# predicted=7.281286, actual=7.270313
# predicted=7.268816, actual=7.265989
# predicted=7.267265, actual=7.254885
# predicted=7.255669, actual=7.244692
# predicted=7.246196, actual=7.251203
# predicted=7.251671, actual=7.239646
# predicted=7.238291, actual=7.271704
# predicted=7.272716, actual=7.276937
# predicted=7.274950, actual=7.275068
# predicted=7.273846, actual=7.285267
# predicted=7.286190, actual=7.278491
# predicted=7.279502, actual=7.271426
# predicted=7.271575, actual=7.286911
# predicted=7.288432, actual=7.279939
# predicted=7.279086, actual=7.282349
# predicted=7.281977, actual=7.285301
# predicted=7.285543, actual=7.311018
# predicted=7.312445, actual=7.322015
# predicted=7.320400, actual=7.322642
# predicted=7.321604, actual=7.318241
# predicted=7.318811, actual=7.311319
# predicted=7.313071, actual=7.319070
# predicted=7.320586, actual=7.318772
# predicted=7.318278, actual=7.329586
# predicted=7.329417, actual=7.384704
# predicted=7.386311, actual=7.387121
# predicted=7.383716, actual=7.389564
# predicted=7.388693, actual=7.398113
# predicted=7.400698, actual=7.389039
# predicted=7.391075, actual=7.386409
# predicted=7.386932, actual=7.376101
# predicted=7.376395, actual=7.374629
# predicted=7.375469, actual=7.377228
# predicted=7.377081, actual=7.393355
# predicted=7.393474, actual=7.388730
# predicted=7.386811, actual=7.377915
# predicted=7.377415, actual=7.376414
# predicted=7.377805, actual=7.383026
# predicted=7.384355, actual=7.389873
# predicted=7.389181, actual=7.382187
# predicted=7.380624, actual=7.385820
# predicted=7.386483, actual=7.384704
# predicted=7.385138, actual=7.384269
# predicted=7.384372, actual=7.389873
# predicted=7.389878, actual=7.396979
# predicted=7.397089, actual=7.404735
# predicted=7.404420, actual=7.407500
# predicted=7.407114, actual=7.415927
# predicted=7.416487, actual=7.397439
# predicted=7.396619, actual=7.402238
# predicted=7.404003, actual=7.405344
# predicted=7.405956, actual=7.398419
# predicted=7.397680, actual=7.388699
# predicted=7.387841, actual=7.385262
# predicted=7.386252, actual=7.376289
# predicted=7.376262, actual=7.395998
# predicted=7.396861, actual=7.397010
# predicted=7.395305, actual=7.396213
# predicted=7.395237, actual=7.403244
# predicted=7.403720, actual=7.395200
# predicted=7.395477, actual=7.395537
# predicted=7.395974, actual=7.402055
# predicted=7.402653, actual=7.384021
# predicted=7.382929, actual=7.377571
# predicted=7.377947, actual=7.374253
# predicted=7.375112, actual=7.376195
# predicted=7.376433, actual=7.357748
# predicted=7.355721, actual=7.372055
# predicted=7.373415, actual=7.377384
# predicted=7.376916, actual=7.378165
# predicted=7.377089, actual=7.368529
# predicted=7.367442, actual=7.383306
# predicted=7.385466, actual=7.400804
# predicted=7.401068, actual=7.404948
# predicted=7.403391, actual=7.415145
# predicted=7.414940, actual=7.422433
# predicted=7.423325, actual=7.435733
# predicted=7.436692, actual=7.407712
# predicted=7.406018, actual=7.387585
# predicted=7.389049, actual=7.386564
# predicted=7.389234, actual=7.379944
# predicted=7.379900, actual=7.394831
# predicted=7.393911, actual=7.379850
# predicted=7.377269, actual=7.413850
# predicted=7.415673, actual=7.409591
# predicted=7.407687, actual=7.411073
# predicted=7.410931, actual=7.410952
# predicted=7.411271, actual=7.408864
# predicted=7.410322, actual=7.412824
# predicted=7.412957, actual=7.413578
# predicted=7.413472, actual=7.422792
# predicted=7.422968, actual=7.420759
# predicted=7.420087, actual=7.417130
# predicted=7.417130, actual=7.412100
# predicted=7.412495, actual=7.402665
# predicted=7.403074, actual=7.406407
# predicted=7.407062, actual=7.386595
# predicted=7.385404, actual=7.379788
# predicted=7.380133, actual=7.370829
# predicted=7.370955, actual=7.373312
# predicted=7.373692, actual=7.377509
# predicted=7.376506, actual=7.376539
# predicted=7.375553, actual=7.367993
# predicted=7.367228, actual=7.387647
# predicted=7.389280, actual=7.394678
# predicted=7.394090, actual=7.396673
# predicted=7.395560, actual=7.396765
# predicted=7.396683, actual=7.370640
# predicted=7.370719, actual=7.357907
# predicted=7.359438, actual=7.355226
# predicted=7.356601, actual=7.340771
# predicted=7.339806, actual=7.347235
# predicted=7.346785, actual=7.360517
# predicted=7.360280, actual=7.353562
# predicted=7.351730, actual=7.364832
# predicted=7.364938, actual=7.362518
# predicted=7.362559, actual=7.354458
# predicted=7.354487, actual=7.352858
# predicted=7.353326, actual=7.357205
# predicted=7.358150, actual=7.365307
# predicted=7.365063, actual=7.370105
# predicted=7.369259, actual=7.383710
# predicted=7.383861, actual=7.384331
# predicted=7.383842, actual=7.410801
# predicted=7.412150, actual=7.418391
# predicted=7.417696, actual=7.413639
# predicted=7.413111, actual=7.416559
# predicted=7.417623, actual=7.429462
# predicted=7.431473, actual=7.433932
# predicted=7.433499, actual=7.418571
# predicted=7.417220, actual=7.414332
# predicted=7.415556, actual=7.418001
# predicted=7.419511, actual=7.421716
# predicted=7.421492, actual=7.423330
# predicted=7.422200, actual=7.431389
# predicted=7.431461, actual=7.417070
# predicted=7.416206, actual=7.421656
# predicted=7.422820, actual=7.427144
# predicted=7.427700, actual=7.431063
# predicted=7.430764, actual=7.430855
# predicted=7.429914, actual=7.434346
# predicted=7.434820, actual=7.454604
# predicted=7.455651, actual=7.393663
# predicted=7.390070, actual=7.405161
# predicted=7.409082, actual=7.405192
# predicted=7.406505, actual=7.409802
# predicted=7.408918, actual=7.410468
# predicted=7.407543, actual=7.419261
# predicted=7.419995, actual=7.424046
# predicted=7.423807, actual=7.406893
# predicted=7.406012, actual=7.401506
# predicted=7.402561, actual=7.405496
# predicted=7.406903, actual=7.406650
# predicted=7.406277, actual=7.403092
# predicted=7.401829, actual=7.400743
# predicted=7.400716, actual=7.387585
# predicted=7.387540, actual=7.383741
# predicted=7.384414, actual=7.387585
# predicted=7.388009, actual=7.399704
# predicted=7.399501, actual=7.400468
# predicted=7.398920, actual=7.384517
# predicted=7.383537, actual=7.380256
# predicted=7.381624, actual=7.381813
# predicted=7.383091, actual=7.380505
# predicted=7.380015, actual=7.377384
# predicted=7.376424, actual=7.382560
# predicted=7.382822, actual=7.383182
# predicted=7.382983, actual=7.384362
# predicted=7.384100, actual=7.378259
# predicted=7.377947, actual=7.379944
# predicted=7.380630, actual=7.378852
# predicted=7.378903, actual=7.366477
# predicted=7.365918, actual=7.379476
# predicted=7.380520, actual=7.380349
# predicted=7.379879, actual=7.382435
# predicted=7.381761, actual=7.399765
# predicted=7.400047, actual=7.404644
# predicted=7.404339, actual=7.404583
# predicted=7.404014, actual=7.399734
# predicted=7.400055, actual=7.413729
# predicted=7.415527, actual=7.424255
# predicted=7.424105, actual=7.439207
# predicted=7.438677, actual=7.449963
# predicted=7.449413, actual=7.454836
# predicted=7.455038, actual=7.422553
# predicted=7.421705, actual=7.423568
# predicted=7.426540, actual=7.414814
# predicted=7.415769, actual=7.412432
# predicted=7.412159, actual=7.407560
# predicted=7.406246, actual=7.398143
# predicted=7.397928, actual=7.403122
# predicted=7.403517, actual=7.405192
# predicted=7.404913, actual=7.425894
# predicted=7.425948, actual=7.425060
# predicted=7.423411, actual=7.429580
# predicted=7.429638, actual=7.431744
# predicted=7.432263, actual=7.424016
# predicted=7.424433, actual=7.425596
# predicted=7.426172, actual=7.436382
# predicted=7.437138, actual=7.432898
# predicted=7.431949, actual=7.422463
# predicted=7.421730, actual=7.404583
# predicted=7.404998, actual=7.409258
# predicted=7.411179, actual=7.415927
# predicted=7.415832, actual=7.402756
# predicted=7.400726, actual=7.395507
# predicted=7.395191, actual=7.409863
# predicted=7.411565, actual=7.409288
# predicted=7.408449, actual=7.408470
# predicted=7.407338, actual=7.408834
# predicted=7.408994, actual=7.399918
# predicted=7.400228, actual=7.389440
# predicted=7.389539, actual=7.384548
# predicted=7.385180, actual=7.381626
# predicted=7.381802, actual=7.376070
# predicted=7.375423, actual=7.371961
# predicted=7.371580, actual=7.371175
# predicted=7.371205, actual=7.366887
# predicted=7.366559, actual=7.369349
# predicted=7.369349, actual=7.364737
# predicted=7.364282, actual=7.353402
# predicted=7.353037, actual=7.363755
# predicted=7.364829, actual=7.371678
# predicted=7.371554, actual=7.364357
# predicted=7.362815, actual=7.359754
# predicted=7.359647, actual=7.361820
# predicted=7.363057, actual=7.368056
# predicted=7.368416, actual=7.361947
# predicted=7.360799, actual=7.374942
# predicted=7.375540, actual=7.384517
# predicted=7.384474, actual=7.392278
# predicted=7.391814, actual=7.397439
# predicted=7.397058, actual=7.400560
# predicted=7.401084, actual=7.404827
# predicted=7.405368, actual=7.404218
# predicted=7.404378, actual=7.415627
# predicted=7.416355, actual=7.395752
# predicted=7.394566, actual=7.354810
# predicted=7.354366, actual=7.348169
# predicted=7.351203, actual=7.332794
# predicted=7.333324, actual=7.333676
# predicted=7.332690, actual=7.338011
# predicted=7.336379, actual=7.330962
# predicted=7.329643, actual=7.328897
# predicted=7.328474, actual=7.330602
# predicted=7.331101, actual=7.318573
# predicted=7.318014, actual=7.332729
# predicted=7.333627, actual=7.336774
# predicted=7.336251, actual=7.335667
# predicted=7.334840, actual=7.323995
# predicted=7.323352, actual=7.329651
# predicted=7.331392, actual=7.339278
# predicted=7.339705, actual=7.345913
# predicted=7.345091, actual=7.336774
# predicted=7.335418, actual=7.332762
# predicted=7.333573, actual=7.340317
# predicted=7.341697, actual=7.326301
# predicted=7.325388, actual=7.323138
# predicted=7.323195, actual=7.328306
# predicted=7.329018, actual=7.317246
# predicted=7.316488, actual=7.310884
# predicted=7.310481, actual=7.288518
# predicted=7.288211, actual=7.292439
# predicted=7.294027, actual=7.303237
# predicted=7.303168, actual=7.297430
# predicted=7.295504, actual=7.296074
# predicted=7.295232, actual=7.297599
# predicted=7.298351, actual=7.302328
# predicted=7.302791, actual=7.309547
# predicted=7.309203, actual=7.304684
# predicted=7.303925, actual=7.307571
# predicted=7.308061, actual=7.303608
# predicted=7.303792, actual=7.307538
# predicted=7.308089, actual=7.305726
# predicted=7.305338, actual=7.316149
# predicted=7.316628, actual=7.318772
# predicted=7.318191, actual=7.316615
# predicted=7.316295, actual=7.316681
# predicted=7.316982, actual=7.325116
# predicted=7.326062, actual=7.321552
# predicted=7.320943, actual=7.327321
# predicted=7.327511, actual=7.334395
# predicted=7.334638, actual=7.332140
# predicted=7.331792, actual=7.351896
# predicted=7.352692, actual=7.351672
# predicted=7.350960, actual=7.349488
# predicted=7.349312, actual=7.383617
# predicted=7.385574, actual=7.392463
# predicted=7.391687, actual=7.394985
# predicted=7.393882, actual=7.396611
# predicted=7.397247, actual=7.410468
# predicted=7.412802, actual=7.409136
# predicted=7.408701, actual=7.399153
# predicted=7.398765, actual=7.396887
# predicted=7.397925, actual=7.408621
# predicted=7.410030, actual=7.412492
# predicted=7.411596, actual=7.411979
# predicted=7.410974, actual=7.410287
# predicted=7.410428, actual=7.412764
# predicted=7.413656, actual=7.430529
# predicted=7.431302, actual=7.421088
# predicted=7.419482, actual=7.428006
# predicted=7.428563, actual=7.440323
# predicted=7.441203, actual=7.441467
# predicted=7.441204, actual=7.443810
# predicted=7.443387, actual=7.437265
# predicted=7.437542, actual=7.437854
# predicted=7.438877, actual=7.422314
# predicted=7.421883, actual=7.432987
# predicted=7.434279, actual=7.427858
# predicted=7.426963, actual=7.416649
# predicted=7.415901, actual=7.408834
# predicted=7.408876, actual=7.412130
# predicted=7.413286, actual=7.407924
# predicted=7.407092, actual=7.403183
# predicted=7.402421, actual=7.422254
# predicted=7.423108, actual=7.426043
# predicted=7.425117, actual=7.337913
# predicted=7.333548, actual=7.303944
# predicted=7.308580, actual=7.293460
# predicted=7.297574, actual=7.263575
# predicted=7.260549, actual=7.283380
# predicted=7.281333, actual=7.268850
# predicted=7.265364, actual=7.282521
# predicted=7.282484, actual=7.275380
# predicted=7.273545, actual=7.287937
# predicted=7.289251, actual=7.290532
# predicted=7.289704, actual=7.276660
# predicted=7.276177, actual=7.275761
# predicted=7.276522, actual=7.275242
# predicted=7.276105, actual=7.265395
# predicted=7.264742, actual=7.246404
# predicted=7.245474, actual=7.246796
# predicted=7.248006, actual=7.237059
# predicted=7.236529, actual=7.240255
# predicted=7.239984, actual=7.232769
# predicted=7.231494, actual=7.254213
# predicted=7.255303, actual=7.258342
# predicted=7.257012, actual=7.256368
# predicted=7.255699, actual=7.282280
# predicted=7.283746, actual=7.271808
# predicted=7.270960, actual=7.258095
# predicted=7.257951, actual=7.258835
# predicted=7.260403, actual=7.260031
# predicted=7.261090, actual=7.258518
# predicted=7.257531, actual=7.250919
# predicted=7.250059, actual=7.246653
# predicted=7.246999, actual=7.265954
# predicted=7.267154, actual=7.267316
# predicted=7.266000, actual=7.272988
# predicted=7.272475, actual=7.274202
# predicted=7.274230, actual=7.276626
# predicted=7.277509, actual=7.263890
# predicted=7.263389, actual=7.285883
# predicted=7.287844, actual=7.286466
# predicted=7.285461, actual=7.283070
# predicted=7.282398, actual=7.281145
# predicted=7.281287, actual=7.276591
# predicted=7.277553, actual=7.278870
# predicted=7.279194, actual=7.266164
# predicted=7.265330, actual=7.276383
# predicted=7.277331, actual=7.274376
# predicted=7.273695, actual=7.262208
# predicted=7.261451, actual=7.272884
# predicted=7.273777, actual=7.277870
# predicted=7.277989, actual=7.293358
# predicted=7.293183, actual=7.299899
# predicted=7.298942, actual=7.301350
# predicted=7.301471, actual=7.331453
# predicted=7.333244, actual=7.345720
# predicted=7.345474, actual=7.343814
# predicted=7.342942, actual=7.345074
# predicted=7.345994, actual=7.337165
# predicted=7.338539, actual=7.325775
# predicted=7.326319, actual=7.309681
# predicted=7.309654, actual=7.319368
# predicted=7.320698, actual=7.309681
# predicted=7.308197, actual=7.333872
# predicted=7.334441, actual=7.321321
# predicted=7.319064, actual=7.318274
# predicted=7.318758, actual=7.320990
# predicted=7.321631, actual=7.320361
# predicted=7.320963, actual=7.319733
# predicted=7.319070, actual=7.332696
# predicted=7.333226, actual=7.326531
# predicted=7.325642, actual=7.334493
# predicted=7.334988, actual=7.326202
# predicted=7.325790, actual=7.328208
# predicted=7.329080, actual=7.317312
# predicted=7.316784, actual=7.301586
# predicted=7.301648, actual=7.277593
# predicted=7.277256, actual=7.270939
# predicted=7.271957, actual=7.282933
# predicted=7.283212, actual=7.286842
# predicted=7.285093, actual=7.271356
# predicted=7.269082, actual=7.286363
# predicted=7.287869, actual=7.288996
# predicted=7.289060, actual=7.285369
# predicted=7.284649, actual=7.285644
# predicted=7.285566, actual=7.308275
# predicted=7.309975, actual=7.324622
# predicted=7.324055, actual=7.331519
# predicted=7.330498, actual=7.333350
# predicted=7.333503, actual=7.318739
# predicted=7.319328, actual=7.323072
# predicted=7.324957, actual=7.334036
# predicted=7.334784, actual=7.360231
# predicted=7.360397, actual=7.301923
# predicted=7.297384, actual=7.347171
# predicted=7.352064, actual=7.352249
# predicted=7.351925, actual=7.360962
# predicted=7.359683, actual=7.353274
# predicted=7.351473, actual=7.355513
# predicted=7.357896, actual=7.361471
# predicted=7.362152, actual=7.365655
# predicted=7.365561, actual=7.375820
# predicted=7.375605, actual=7.382622
# predicted=7.382537, actual=7.413277
# predicted=7.414220, actual=7.420190
# predicted=7.419236, actual=7.418031
# predicted=7.417815, actual=7.422015
# predicted=7.423456, actual=7.445038
# predicted=7.447197, actual=7.439265
# predicted=7.438018, actual=7.436116
# predicted=7.436052, actual=7.428808
# predicted=7.429744, actual=7.441438
# predicted=7.443065, actual=7.456223
# predicted=7.455821, actual=7.477972
# predicted=7.477415, actual=7.454228
# predicted=7.452165, actual=7.407378
# predicted=7.407641, actual=7.399612
# predicted=7.403628, actual=7.400315
# predicted=7.401677, actual=7.393940
# predicted=7.391222, actual=7.391354
# predicted=7.389358, actual=7.391847
# predicted=7.391803, actual=7.391477
# predicted=7.391294, actual=7.390027
# predicted=7.389632, actual=7.386966
# predicted=7.386843, actual=7.382311
# predicted=7.382332, actual=7.404005
# predicted=7.405061, actual=7.389193
# predicted=7.387378, actual=7.380287
# predicted=7.380148, actual=7.388080
# predicted=7.389605, actual=7.389039
# predicted=7.389201, actual=7.380910
# predicted=7.379526, actual=7.387431
# predicted=7.387996, actual=7.387555
# predicted=7.387674, actual=7.401720
# predicted=7.401906, actual=7.414061
# predicted=7.413617, actual=7.387555
# predicted=7.385968, actual=7.378509
# predicted=7.379940, actual=7.392340
# predicted=7.394751, actual=7.404096
# predicted=7.403524, actual=7.408652
# predicted=7.406520, actual=7.414633
# predicted=7.414495, actual=7.379757
# predicted=7.379026, actual=7.382622
# predicted=7.385262, actual=7.397623
# predicted=7.398938, actual=7.397286
# predicted=7.395512, actual=7.401048
# predicted=7.399555, actual=7.393755
# predicted=7.393872, actual=7.397133
# predicted=7.398261, actual=7.393294
# predicted=7.393178, actual=7.402421
# predicted=7.402852, actual=7.401079
# predicted=7.400356, actual=7.400682
# predicted=7.400625, actual=7.401567
# predicted=7.401764, actual=7.400560
# predicted=7.400833, actual=7.394462
# predicted=7.394215, actual=7.400834
# predicted=7.401441, actual=7.403549
# predicted=7.403384, actual=7.405769
# predicted=7.405356, actual=7.400590
# predicted=7.400169, actual=7.406407
# predicted=7.407240, actual=7.408743
# predicted=7.408763, actual=7.404827
# predicted=7.404391, actual=7.418541
# predicted=7.419180, actual=7.418151
# predicted=7.417736, actual=7.421148
# predicted=7.421039, actual=7.419860
# predicted=7.419910, actual=7.435320
# predicted=7.436481, actual=7.443371
# predicted=7.442876, actual=7.462330
# predicted=7.462408, actual=7.472955
# predicted=7.472594, actual=7.477633
# predicted=7.477850, actual=7.483863
# predicted=7.484638, actual=7.486305
# predicted=7.487151, actual=7.468884
# predicted=7.468614, actual=7.457061
# predicted=7.457961, actual=7.453678
# predicted=7.454828, actual=7.427739
# predicted=7.426666, actual=7.413156
# predicted=7.412961, actual=7.388823
# predicted=7.388388, actual=7.409167
# predicted=7.410497, actual=7.398266
# predicted=7.395522, actual=7.416018
# predicted=7.415517, actual=7.409136
# predicted=7.407792, actual=7.431359
# predicted=7.432662, actual=7.428987
# predicted=7.428051, actual=7.438266
# predicted=7.438799, actual=7.422463
# predicted=7.421988, actual=7.427650
# predicted=7.429249, actual=7.455125
# predicted=7.456358, actual=7.446906
# predicted=7.444917, actual=7.459224
# predicted=7.459134, actual=7.467171
# predicted=7.468129, actual=7.463593
# predicted=7.463682, actual=7.458301
# predicted=7.458262, actual=7.468428
# predicted=7.469887, actual=7.458532
# predicted=7.457945, actual=7.459166
# predicted=7.459201, actual=7.460087
# predicted=7.460394, actual=7.446643
# predicted=7.446180, actual=7.471847
# predicted=7.473000, actual=7.470367
# predicted=7.469300, actual=7.465398
# predicted=7.464481, actual=7.469911
# Test RMSE: 0.013

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Calculate metrics
mae = mean_absolute_error(test_slice, predictions)
mse = mean_squared_error(test_slice, predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((test_slice - predictions) / test_slice)) * 100
r2 = r2_score(test_slice, predictions)

print(f'Mean Absolute Error (MAE): {mae:.3f}')
print(f'Mean Squared Error (MSE): {mse:.3f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.3f}')
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
print(f'R-squared (R²): {r2:.3f}')
# Out:
# Mean Absolute Error (MAE): 0.009
# Mean Squared Error (MSE): 0.000
# Root Mean Squared Error (RMSE): 0.013
# Mean Absolute Percentage Error (MAPE): 0.12%
# R-squared (R²): 0.959

# %%
# from statsmodels.tsa.arima.model import ARIMA
# from sklearn.metrics import mean_squared_error
# import numpy as np
# import matplotlib.pyplot as plt

# x = y.values
# train_size = int(len(x) * 0.7)
# train, test = x[0:train_size], x[train_size:]
# history = [x for x in train]
# predictions = []

# for t in range(len(test)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()  # No disp argument
#     output = model_fit.forecast(steps=1)
#     yhat = output[0]
#     predictions.append(yhat)
#     obs = test[t]
#     history.append(obs)
#     print('predicted=%f, actual=%f' % (yhat, obs))

# error = mean_squared_error(test, predictions)
# print('Test RMSE: %.3f' % np.sqrt(error))

# plt.plot(test, label='Actual')
# plt.plot(predictions, color='red', label='Predicted')
# plt.legend()
# plt.show()

# %% [markdown]
# # 5. Making the predictions

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Assume y is your log-transformed time series data and already loaded
x_log = y.values

# Fit the ARIMA model on the log-transformed data
model = ARIMA(x_log, order=(5,1,0))  # p, d, q
model_fit = model.fit()

# Forecast the next value in the log-transformed scale
forecast_log = model_fit.forecast(steps=1) # next day
forecast_log_value = forecast_log[0]

# Reverse the logarithmic transformation to get the actual price
forecast_value = np.exp(forecast_log_value)

# Get tomorrow's date
today = datetime.now()
tomorrow = today + timedelta(days=1)
tomorrow_date_str = tomorrow.strftime('%Y-%m-%d')  # Format date as YYYY-MM-DD

print(f'The predicted stock price for {tomorrow_date_str} is: {forecast_value:.2f}')
# Out:
# The predicted stock price for 2024-11-13 is: 1755.74

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assume y is your log-transformed time series data and already loaded
x_log = y.values

# Fit the ARIMA model on the log-transformed data
model = ARIMA(x_log, order=(5,1,0))  # p, d, q
model_fit = model.fit()

# Forecast the next 10 days in the log-transformed scale
forecast_log = model_fit.forecast(steps=10)
forecast_log_values = forecast_log

# Reverse the logarithmic transformation to get the actual prices
forecast_values = np.exp(forecast_log_values)

# Generate dates for the next 10 days
last_date = pd.to_datetime('today')  # Adjust if you have a specific end date
dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=10, freq='D')

# Create a DataFrame to display results
forecast_df = pd.DataFrame({
    'Date': dates,
    'Forecasted Price': forecast_values
})

print(forecast_df)

# Optional: Plot the forecasted prices
plt.figure(figsize=(12, 6))
plt.plot(dates, forecast_values, marker='o', linestyle='-', color='red', label='Forecasted Prices')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Forecasted Stock Prices for the Next 10 Days')
plt.legend()
plt.grid()
plt.show()
# Out:
#                         Date  Forecasted Price
# 0 2024-11-13 20:29:27.190274       1755.738020
# 1 2024-11-14 20:29:27.190274       1757.223118
# 2 2024-11-15 20:29:27.190274       1756.682071
# 3 2024-11-16 20:29:27.190274       1756.478834
# 4 2024-11-17 20:29:27.190274       1756.841850
# 5 2024-11-18 20:29:27.190274       1756.975567
# 6 2024-11-19 20:29:27.190274       1757.006778
# 7 2024-11-20 20:29:27.190274       1756.966371
# 8 2024-11-21 20:29:27.190274       1756.965232
# 9 2024-11-22 20:29:27.190274       1756.986035

# %%
# # Example data setup (ensure y is defined and contains your time series data)
# x = y.values  # y is your data series
# train_size = int(len(x) * 0.6)  # 60% for training
# validation_size = int(len(x) * 0.2)  # 20% for validation

# # Split the data into training, validation, and testing
# train = x[:train_size]
# validation = x[train_size:train_size + validation_size]
# test = x[train_size + validation_size:]

# history = list(train)  # Use list() to ensure history is a list
# validation_predictions = []
# test_predictions = []

# # 1. Validation predictions
# for t in range(len(validation)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()
#     output = model_fit.forecast(steps=1)
#     yhat = output[0]
#     validation_predictions.append(yhat)
#     obs = validation[t]
#     history.append(obs)
#     print(f'Validation - predicted={yhat:.6f}, actual={obs:.6f}')

# # 2. Test predictions
# for t in range(len(test)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()
#     output = model_fit.forecast(steps=1)
#     yhat = output[0]
#     test_predictions.append(yhat)
#     obs = test[t]
#     history.append(obs)
#     print(f'Test - predicted={yhat:.6f}, actual={obs:.6f}')

# # Calculate RMSE for validation and test sets
# validation_error = mean_squared_error(validation, validation_predictions)
# test_error = mean_squared_error(test, test_predictions)

# print(f'Validation RMSE: {np.sqrt(validation_error):.3f}')
# print(f'Test RMSE: {np.sqrt(test_error):.3f}')

# # Plot the results
# plt.figure(figsize=(14, 7))

# # Plot training data
# plt.plot(range(len(train)), train, label='Training Data', color='green')

# # Plot validation predictions and actual validation data
# plt.plot(range(len(train), len(train) + len(validation)), validation, label='Validation Data', color='blue')
# plt.plot(range(len(train), len(train) + len(validation)), validation_predictions, label='Validation Predictions', linestyle='--', color='orange')

# # Plot test predictions and actual test data
# plt.plot(range(len(train) + len(validation), len(x)), test, label='Test Data', color='blue')
# plt.plot(range(len(train) + len(validation), len(x)), test_predictions, label='Test Predictions', linestyle='--', color='red')

# plt.xlabel('Time')
# plt.ylabel('Stock Price')
# plt.title('Training, Validation, and Test Data vs Predictions')
# plt.legend()
# plt.show()

# %% [markdown]
# 2. SARIMA

# %%
warnings.filterwarnings("ignore", message="Maximum Likelihood optimization failed to converge")

x = y.values
train_size = int(len(x) * 0.7)
train, test = x[0:train_size], x[train_size:]

history = list(train)  # Use list() to ensure history is a list
predictions = []

# Define SARIMA parameters
# Adjust the (p, d, q) and (P, D, Q, s) parameters based on your data
seasonal_period = 12  # Example: monthly data with yearly seasonality
num_predictions = 20
cnt = 0

for t in range(len(test)):
    if cnt == num_predictions:
        break
    model = SARIMAX(history, order=(5,1,0), seasonal_order=(1,1,1,seasonal_period))
    model_fit = model.fit(disp=False)  # No disp argument
    output = model_fit.forecast(steps=1)
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'predicted={yhat:.6f}, actual={obs:.6f}')
    cnt += 1

# Ensure predictions and test have the same length
if len(predictions) != num_predictions:
    raise ValueError(f"Predictions length ({len(predictions)}) does not match expected number ({num_predictions})")

# Slice the test set to match the length of predictions
test_slice = test[:num_predictions]

# Calculate error
error = mean_squared_error(test_slice, predictions)
print(f'Test RMSE: {np.sqrt(error):.3f}')

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(test_slice, label='Actual', color='blue')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Actual vs Predicted Stock Prices')
plt.legend()
plt.show()
# Out:
# predicted=7.208261, actual=7.206377
# predicted=7.206820, actual=7.210634
# predicted=7.211185, actual=7.212036
# predicted=7.213210, actual=7.209784
# predicted=7.208449, actual=7.223478
# predicted=7.223198, actual=7.241223
# predicted=7.240599, actual=7.242154
# predicted=7.243226, actual=7.248611
# predicted=7.249613, actual=7.238353
# predicted=7.239420, actual=7.213658
# predicted=7.214386, actual=7.208637
# predicted=7.210339, actual=7.216746
# predicted=7.221950, actual=7.206043
# predicted=7.202511, actual=7.206414
# predicted=7.206586, actual=7.218946
# predicted=7.221669, actual=7.215791
# predicted=7.213643, actual=7.238856
# predicted=7.238592, actual=7.241796
# predicted=7.240162, actual=7.239753
# predicted=7.242584, actual=7.247365
# Test RMSE: 0.011

# %%
# Calculate metrics
mae = mean_absolute_error(test_slice, predictions)
mse = mean_squared_error(test_slice, predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((test_slice - predictions) / test_slice)) * 100
r2 = r2_score(test_slice, predictions)

print(f'Mean Absolute Error (MAE): {mae:.3f}')
print(f'Mean Squared Error (MSE): {mse:.3f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.3f}')
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
print(f'R-squared (R²): {r2:.3f}')
# Out:
# Mean Absolute Error (MAE): 0.009
# Mean Squared Error (MSE): 0.000
# Root Mean Squared Error (RMSE): 0.011
# Mean Absolute Percentage Error (MAPE): 0.12%
# R-squared (R²): 0.449

# %%
model = SARIMAX(x_log, order=(5,1,0), seasonal_order=(1,1,1,12))  # Example parameters
model_fit = model.fit(disp=False)

# Forecast the next value in the log-transformed scale
forecast_log = model_fit.forecast(steps=1) # next day
forecast_log_value = forecast_log[0]

# Reverse the logarithmic transformation to get the actual price
forecast_value = np.exp(forecast_log_value)

# Get tomorrow's date
today = datetime.now()
tomorrow = today + timedelta(days=1)
tomorrow_date_str = tomorrow.strftime('%Y-%m-%d')  # Format date as YYYY-MM-DD

print(f'The predicted stock price for {tomorrow_date_str} is: {forecast_value:.2f}')
# Out:
# The predicted stock price for 2024-11-13 is: 1761.68

# %%
# Assume y is your log-transformed time series data and already loaded
x_log = y.values

# Define the SARIMA model
# Example parameters; adjust these based on your data and seasonal period
model = SARIMAX(x_log, order=(5,1,0), seasonal_order=(1,1,1,12))  # Adjust parameters as needed
model_fit = model.fit(disp=False)

# Forecast the next 10 days in the log-transformed scale
forecast_log = model_fit.forecast(steps=10)
forecast_log_values = forecast_log

# Reverse the logarithmic transformation to get the actual prices
forecast_values = np.exp(forecast_log_values)

# Generate dates for the next 10 days
today = datetime.now()
dates = [today + timedelta(days=i+1) for i in range(10)] 
dates_str = [date.strftime('%Y-%m-%d') for date in dates]

# Create a DataFrame to display results
forecast_df = pd.DataFrame({
    'Date': dates_str,
    'Forecasted Price': forecast_values
})

print(forecast_df)

# Optional: Plot the forecasted prices
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(dates, forecast_values, marker='o', linestyle='-', color='red', label='Forecasted Prices')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Forecasted Stock Prices for the Next 10 Days')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
#          Date  Forecasted Price
# 0  2024-11-13       1761.681335
# 1  2024-11-14       1764.421650
# 2  2024-11-15       1765.191227
# 3  2024-11-16       1764.799068
# 4  2024-11-17       1762.961390
# 5  2024-11-18       1766.762048
# 6  2024-11-19       1767.373628
# 7  2024-11-20       1767.275253
# 8  2024-11-21       1770.278268
# 9  2024-11-22       1768.563915

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from statsmodels.tsa.arima.model import ARIMA

# # Assume y is your log-transformed time series data and already loaded
# x_log = y.values
# train_size = int(len(x_log) * 0.7)
# train, test = x_log[0:train_size], x_log[train_size:]
# test_actual = np.exp(test)  # Convert test data back to original scale
# history = [x for x in train]
# predictions = []

# # Forecasting the test period
# for t in range(len(test)):
#     model = ARIMA(history, order=(5,1,0))  # p, d, q
#     model_fit = model.fit()
#     output = model_fit.forecast(steps=1)
#     yhat_log = output[0]
#     yhat = np.exp(yhat_log)  # Convert forecasted log value back to original scale
#     predictions.append(yhat)
#     obs = np.exp(test[t])  # Ensure actual test values are in original scale
#     history.append(test[t])
#     # print('predicted=%f, actual=%f' % (yhat, obs))

# # Convert predictions to a numpy array for easy plotting
# predictions = np.array(predictions)

# # Plot actual vs predicted prices
# plt.figure(figsize=(12, 6))
# plt.plot(test_actual, label='Actual Prices', color='blue')
# plt.plot(predictions, color='red', label='Predicted Prices')
# plt.xlabel('Time')
# plt.ylabel('Stock Price')
# plt.title('Actual vs Predicted Stock Prices')
# plt.legend()
# plt.show()
